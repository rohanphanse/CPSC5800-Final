# %%
from ultralytics import YOLO
import skimage
import matplotlib.pyplot as plt
import cv2
import numpy as np

base_model = YOLO("yolov8n.pt")
base_model.info()
# Out:
# YOLOv8n summary: 129 layers, 3,157,200 parameters, 0 gradients, 8.9 GFLOPs
# (129, 3157200, 0, 8.8575488)

# %%
def config_plot():
    '''
    Function to remove axis tickers and box around figure
    '''
    plt.box(False)
    plt.axis('off')

images = {
    "Astronaut": skimage.data.astronaut(),
    "Coffee": skimage.data.coffee(),
}

for title, img in images.items():
    results = model(img)
    result_img = results[0].plot()

    plt.figure(figsize=(8, 6))
    plt.imshow(result_img)
    plt.title(title)
    config_plot()
    plt.show()
# Out:
# 0: 640x640 1 person, 83.9ms
# Speed: 4.3ms preprocess, 83.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 0: 448x640 1 cup, 1 dining table, 45.1ms
# Speed: 1.2ms preprocess, 45.1ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
